# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading from Files

# %% [markdown]
# ## CVS file

# %%
df = pd.read_csv("data/bikes.csv", sep = ";", encoding = 'latin1')
df.head()
# Out:
#          Date  Berri 1  Brébeuf (données non disponibles)  \
# 0  01/01/2012       35                                NaN
# 1  02/01/2012       83                                NaN
# 2  03/01/2012      135                                NaN
# 3  04/01/2012      144                                NaN
# 4  05/01/2012      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# ...

# %% [markdown]
# ## Set Date as the index of the row

# %%
df = pd.read_csv("data/bikes.csv", sep = ';', encoding = 'latin1', index_col = 'Date')
df.head()
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 01/01/2012       35                                NaN                      0
# 02/01/2012       83                                NaN                      1
# 03/01/2012      135                                NaN                      2
# 04/01/2012      144                                NaN                      1
# 05/01/2012      197                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 01/01/2012             38             51       26            10       16
# 02/01/2012             68            153       53             6       43
# 03/01/2012            104            248       89             3       58
# 04/01/2012            116            318      111             8       61
# 05/01/2012            124            330       97            13       95
#
# ...

# %%
pd.set_option('display.mpl_style', 'default')
figsize(15,5)
df['Berri 1'].plot()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-40-b3bc134160fa> in <module>()
# ----> 1 pd.set_option('display.mpl_style', 'default')
#       2 figsize(15,5)
#       3 df['Berri 1'].plot()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     222
#     223     def __call__(self, *args, **kwds):
# --> 224         return self.__func__(*args, **kwds)
#     225
#     226     @property
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      81         if not silent:
# ...
